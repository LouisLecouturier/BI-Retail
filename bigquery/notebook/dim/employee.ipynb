# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..", "..")))

# %%
# %pip install google-cloud-bigquery
# %pip install pandas
# %pip install db-dtypes
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from google.cloud import bigquery
import pandas as pd

from utils.import_table import import_table
from utils.export import export_table

# %%
# Initialiser le client BigQuery
client = bigquery.Client.from_service_account_json('../../key.json')

# %%
employee = import_table(client, 'employee', dataset_id="ensemble_de_donnees_public")

employee = employee.drop(columns=['supervised_by'])

employee[['firstname', 'lastname']] = employee['name'].str.split(expand=True)

employee = employee.drop(columns=['name'])

employee = employee.sort_values(by=['id'])


display(employee)
# Out:
# /Users/antoine/miniconda3/envs/AI/lib/python3.11/site-packages/google/cloud/bigquery/table.py:1727: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#     id                                datastream_metadata  firstname lastname
# 4    1  {'uuid': '3c5c5bf5-dead-45c8-821f-6b8010111010...     Willie  Morales
# 3    2  {'uuid': '3c5c5bf5-dead-45c8-821f-6b8010111011...     Thomas  Frazier
# 8    3  {'uuid': '3c5c5bf5-dead-45c8-821f-6b8010111100...     Monica  Simpson
# 5    4  {'uuid': '3c5c5bf5-dead-45c8-821f-6b8010111101...    Chelsea    Smith
# 6    5  {'uuid': '3c5c5bf5-dead-45c8-821f-6b8010111110...    Anthony     Ross
# 7    6  {'uuid': '3c5c5bf5-dead-45c8-821f-6b8010111111...     Joshua   Butler
# 0    7  {'uuid': '3c5c5bf5-dead-45c8-821f-6b8011000000...       John     Gray
# 2    8  {'uuid': '3c5c5bf5-dead-45c8-821f-6b8011000001...     Jeremy  Jimenez
# ...

# %%
# Variables pour BigQuery
dataset_name = "warehouse"
table_name = "employee"

export_table(client=client, df=employee, dataset_name=dataset_name, table_name=table_name, project_id="power-bi-m2")
# Out:
# Dataset warehouse déjà existant.
# 100%|██████████| 1/1 [00:00<00:00, 9258.95it/s]
